# %%
from pydantic import BaseModel, Field
from typing import List, Optional, Dict, Any, Annotated


class Patient(BaseModel):

    name_1: str = Field(title = "This is where you add name.", description="Enter the name of the patients", examples= ["Arjun", "Jasreen"]) 
    name_2: Annotated[str, Field(title = "This is where you add name.", description="Enter the name of the patients", examples= ["Arjun", "Jasreen"])]
